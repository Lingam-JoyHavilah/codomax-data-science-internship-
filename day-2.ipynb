# %%
# Day 2 - Python Basics

# %%
name = "Joy"
age = 20
print("Name:", name)
print("Age:", age)
# Out:
# Name: Joy
# Age: 20

# %%
a = 10
b = 10.5
c = "Python"
d = True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
x = 20
y = 5
print("Addition:", x + y)
print("Subtraction:", x - y)
print("Multiplication:", x * y)
print("Division:", x / y)
print("Modulus:", x % y)
# Out:
# Addition: 25
# Subtraction: 15
# Multiplication: 100
# Division: 4.0
# Modulus: 0

# %%
print(x > y)
print(x < y)
print(x == y)
print(x != y)
# Out:
# True
# False
# False
# True

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count = 1
while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def greet(name):
    print("Hello,", name)
greet("Joy")
# Out:
# Hello, Joy

# %%
num = 10
if num % 2 == 0:
    print(num, "is Even")
else:
    print(num, "is Odd")
# Out:
# 10 is Even

# %%
def add(a, b):
    return a + b
print("Sum:", add(10, 20))
# Out:
# Sum: 30
