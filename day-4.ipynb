# %% [markdown]
# # Day 4 - Pandas Basics

# %%
import pandas as pd
print("Pandas imported successfully!")
# Out:
# Pandas imported successfully!

# %%
df = pd.read_csv("students.csv")
print(df)
# Out:
#          Name  Age  Marks
# 0         Joy   20     95
# 1     Snuhith   21     88
# 2       Rishi   20     91
# 3     Havilah   22     84
# 4      Blessy   21     97
# 5     Sudheer   20     89
# 6        Rupa   22     93
# 7       Kumar   21     85
# 8  Theophilus   20     96
# 9         Raj   22     87

# %%
print(df.head())
# Out:
#       Name  Age  Marks
# 0      Joy   20     95
# 1  Snuhith   21     88
# 2    Rishi   20     91
# 3  Havilah   22     84
# 4   Blessy   21     97

# %%
print(df.tail())
# Out:
#          Name  Age  Marks
# 5     Sudheer   20     89
# 6        Rupa   22     93
# 7       Kumar   21     85
# 8  Theophilus   20     96
# 9         Raj   22     87

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     str
#  1   Age     10 non-null     int64
#  2   Marks   10 non-null     int64
# dtypes: int64(2), str(1)
# memory usage: 372.0 bytes

# %%
print(df.shape)
# Out:
# (10, 3)

# %%
print(df.describe())
# Out:
#              Age      Marks
# count  10.000000  10.000000
# mean   20.900000  90.500000
# std     0.875595   4.624812
# min    20.000000  84.000000
# 25%    20.000000  87.250000
# 50%    21.000000  90.000000
# 75%    21.750000  94.500000
# max    22.000000  97.000000

# %%
print(df["Marks"])
# Out:
# 0    95
# 1    88
# 2    91
# 3    84
# 4    97
# 5    89
# 6    93
# 7    85
# 8    96
# 9    87
# Name: Marks, dtype: int64
